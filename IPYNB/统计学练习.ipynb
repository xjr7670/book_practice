# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
df = pd.read_csv("Documents/score.csv")

# %%
df.plot.hist(table=True)
